# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\\dsml\\ML\\final as\\CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
x=df.drop(columns=['price','car_ID','CarName'])
y=df['price']

# %%
x_e = pd.get_dummies(x, drop_first=True)

# %%
x_e
# Out:
#      symboling  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0            3       88.6      168.8      64.1       48.8        2548
# 1            3       88.6      168.8      64.1       48.8        2548
# 2            1       94.5      171.2      65.5       52.4        2823
# 3            2       99.8      176.6      66.2       54.3        2337
# 4            2       99.4      176.6      66.4       54.3        2824
# ..         ...        ...        ...       ...        ...         ...
# 200         -1      109.1      188.8      68.9       55.5        2952
# 201         -1      109.1      188.8      68.8       55.5        3049
# 202         -1      109.1      188.8      68.9       55.5        3012
# 203         -1      109.1      188.8      68.9       55.5        3217
# 204         -1      109.1      188.8      68.9       55.5        3062
#
#      enginesize  boreratio  stroke  compressionratio  ...  \
# 0           130       3.47    2.68               9.0  ...
# 1           130       3.47    2.68               9.0  ...
# 2           152       2.68    3.47               9.0  ...
# 3           109       3.19    3.40              10.0  ...
# 4           136       3.19    3.40               8.0  ...
# ..          ...        ...     ...               ...  ...
# 200         141       3.78    3.15               9.5  ...
# 201         141       3.78    3.15               8.7  ...
# 202         173       3.58    2.87               8.8  ...
# 203         145       3.01    3.40              23.0  ...
# 204         141       3.78    3.15               9.5  ...
#
#      cylindernumber_three  cylindernumber_twelve  cylindernumber_two  \
# 0                   False                  False               False
# 1                   False                  False               False
# 2                   False                  False               False
# 3                   False                  False               False
# 4                   False                  False               False
# ..                    ...                    ...                 ...
# 200                 False                  False               False
# 201                 False                  False               False
# 202                 False                  False               False
# 203                 False                  False               False
# 204                 False                  False               False
#
#      fuelsystem_2bbl  fuelsystem_4bbl  fuelsystem_idi  fuelsystem_mfi  \
# 0              False            False           False           False
# 1              False            False           False           False
# 2              False            False           False           False
# 3              False            False           False           False
# 4              False            False           False           False
# ..               ...              ...             ...             ...
# 200            False            False           False           False
# 201            False            False           False           False
# 202            False            False           False           False
# 203            False            False            True           False
# 204            False            False           False           False
#
#      fuelsystem_mpfi  fuelsystem_spdi  fuelsystem_spfi
# 0               True            False            False
# 1               True            False            False
# 2               True            False            False
# 3               True            False            False
# 4               True            False            False
# ..               ...              ...              ...
# 200             True            False            False
# 201             True            False            False
# 202             True            False            False
# 203            False            False            False
# 204             True            False            False
#
# [205 rows x 43 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_e, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42),
    "Support Vector Regressor": SVR()
}

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
result={}
for name,model in models.items():
    model.fit(x_train_scaled,y_train)
    y_pred=model.predict(x_test_scaled)
    result[name]={
    'MAE':mean_absolute_error(y_test,y_pred),
    'MSE':mean_squared_error(y_test,y_pred),
    'r2':r2_score(y_test,y_pred)
    }

# %%
result_df=pd.DataFrame(result).T

# %%
result_df
# Out:
#                                   MAE           MSE        r2
# Linear Regression         2089.382729  8.482008e+06  0.892557
# Decision Tree             1886.321146  8.300272e+06  0.894859
# Random Forest             1259.757695  3.313970e+06  0.958021
# Gradient Boosting         1676.027625  5.900139e+06  0.925262
# Support Vector Regressor  5697.657697  8.682982e+07 -0.099891

# %%
best_model = result_df['r2'].idxmax()
best_model
# Out:
# 'Random Forest'

# %% [markdown]
# Random forest is best beacuse of its high r2 value

# %%
rand=RandomForestRegressor()
rand.fit(x_train_scaled,y_train)
importan_features=rand.feature_importances_

# %%
importan_features
# Out:
# array([1.28457268e-03, 8.04858677e-03, 1.15686948e-02, 1.41042995e-02,
#        3.93484930e-03, 2.58475448e-01, 5.74392170e-01, 4.50506532e-03,
#        4.33098568e-03, 4.05422817e-03, 2.86974307e-02, 7.81255268e-03,
#        9.26678108e-03, 5.65731170e-02, 7.00662927e-05, 8.82393033e-04,
#        3.49229841e-04, 6.51634642e-04, 1.03685745e-03, 1.88459521e-03,
#        3.70933902e-04, 4.89109766e-04, 1.82493105e-03, 1.46545857e-08,
#        8.48049952e-05, 1.16088768e-04, 1.67754756e-03, 1.47173553e-04,
#        1.11047090e-04, 2.61525959e-05, 4.66246913e-05, 1.17669270e-03,
#        4.76200919e-04, 0.00000000e+00, 3.12851249e-06, 6.85535198e-06,
#        3.54356441e-04, 3.37961483e-05, 7.35193427e-05, 8.50666272e-05,
#        9.11556734e-04, 4.31313954e-05, 1.77092779e-05])

# %%
e = pd.DataFrame({
    'Feature': x_e.columns,
    'Importance': importan_features
})

# %%
e = e.sort_values(by='Importance', ascending=False)

# %%
e.head()
# Out:
#        Feature  Importance
# 6   enginesize    0.574392
# 5   curbweight    0.258475
# 13  highwaympg    0.056573
# 10  horsepower    0.028697
# 3     carwidth    0.014104

# %% [markdown]
# These are top 5 features affecting car price

# %%
plt.figure(figsize=(10,6))
plt.barh(e['Feature'][:10], e['Importance'][:10])
plt.xlabel("Importance")
plt.title("Top 10 Important Features")
plt.show()

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 15, None],
    'min_samples_split': [2, 5]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
rf=GridSearchCV(RandomForestRegressor(random_state=42),param_grid,cv=5)
rf.fit(x_train_scaled,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#              param_grid={'max_depth': [10, 15, None],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]})

# %%
g=rf.best_estimator_

# %%
yp=g.predict(x_test_scaled)

# %%
r2_score(y_test,yp)
# Out:
# 0.9580212712204378

# %%
rf.best_params_
# Out:
# {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# its same as the default
